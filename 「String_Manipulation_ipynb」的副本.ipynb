# %% [markdown]
# ### **String Manipulation: Concatenation and Repetition**
#
# **String Concatenation:**
# - **Definition:** Combining two or more strings end-to-end.
# - **Operator:** The `+` operator is used for string concatenation.
# - **Example:**
#   ```python
#   first_name = "John"
#   last_name = "Doe"
#   full_name = first_name + " " + last_name  # Results in "John Doe"
#   ```
#
# **String Repetition:**
# - **Definition:** Repeating a string multiple times.
# - **Operator:** The `*` operator is used for string repetition.
# - **Example:**
#   ```python
#   word = "echo"
#   repeated_word = word * 3  # Results in "echoechoecho"
#   ```

# %% [markdown]
# **Practice:**
# 1. **Fruit Salad:** Ask the user for their two favorite fruits. Concatenate them to form a new fruit name.

# %%
#Ex1
favorite_fruit1 = input("Enter your first favorite fruit: ")
favorite_fruit2 = input("Enter your second favorite fruit: ")

new_fruit = favorite_fruit1 + favorite_fruit2
print("your new fruit name is", new_fruit)
# Out:
# Enter your first favorite fruit: apple
# Enter your second favorite fruit: orenge
# your new fruit name is appleorenge

# %% [markdown]
# 2. **Echo Chamber:** Ask the user for a word and a number. Repeat the word as many times as the number they've provided.

# %%
#Ex2
word = input("Please enter a word: ")
number = int(input("Please enter a number: "))

output = word * number
print(output)
# Out:
# Please enter a word: Michael
# Please enter a number: 99999
# Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael Michael  ...

# %% [markdown]
# 3. **Full Name Formatter:** Ask the user for their first name, middle name, and last name. Display their full name by concatenating these strings.

# %%
#Ex3
first_name = input("What is your first name")
middle_name = input("What is your middle name")
last_name = input("What is your last name")
print(first_name + middle_name +last_name)
# Out:
# What is your first namebrad
# What is your middle namebrad
# What is your last namelin
# bradbradlin

# %% [markdown]
# ### **Basic String Methods**
#
# **String Methods:**
# - **Definition:** Built-in functions in Python that can be called on a string to perform specific operations.
# - **Common Methods:**
#   - `upper()`: Converts the string to uppercase.
#   - `lower()`: Converts the string to lowercase.
#   - `title()`: Converts the string to title case (first letter of each word is capitalized).
#   - `len()`: Returns the length of the string.
#
# **String Slicing and Indexing:**
# - **Indexing:** Accessing a single character in a string using its position. Python string indices start at 0.
#   ```python
#   word = "python"
#   first_letter = word[0]  # Results in "p"
#   ```
# - **Slicing:** Accessing a range of characters in a string.
#   ```python
#   word = "python"
#   slice_word = word[1:4]  # Results in "yth"
#   ```

# %% [markdown]
# **Practice:**
# 1. **Name Formatter:**
#    - Ask the user for their full name.
#    - Display their name in uppercase, lowercase, and title case.
#    - Show the length of their name.

# %%
#Ex1
full_name = input("What is your full name:")
full= input().upper()
print(full)
full1= input().lower()
print(full1)
full2= input().title()
print(full2)
var = len(full2)
print(var)
# Out:
# What is your full name:michael
# michael
# MICHAEL
# michael
# michael
# michael
# Michael
# 7

# %% [markdown]
# 2. **Initials Extractor:**
#    - Ask the user for their first name and last name.
#    - Display their initials by extracting the first character from both names.

# %%
#Ex2
first_name = input("What is your first name:")
last_name = input("What is your last name")
first_letter = first_name[0]
print(first_letter)
seconed_letter = last_name[0]
print(seconed_letter)
# Out:
# What is your first name:michael
# What is your last nameli
# m
# l

# %% [markdown]
# *CHALLENGE!!!
# This is a tough one that requires concepts we have not learnt in class yet!*
# 3. **Secret Code:**
#    - Ask the user for a word.
#    - Display the word with every second letter in uppercase and the others in lowercase.

# %%
#Ex3
Word = input("Give me a word:")
slice_word = Word[1:4]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-1729c6714335> in <cell line: 2>()
#       1 #Ex3
# ----> 2 Word = input("Give me a word:")
#       3 slice_word = Word[1:4]
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
